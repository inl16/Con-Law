# %%
start = input("this analysis  is going to comprise of four basic questions. type (wealth) to continue: ")

if start=="wealth":
    print("\n let us begin.  ")
    historical_1=input("Historical Arguments - Q)1 does it depend on a determination of the original understanding \n of the constitutional provision to be construed: ? type yes or no ")
    
    if historical_1=='yes':
        print("\n great. this is one aspect. onto the next ")
        while True:
            historical_2=input("Q)2 - so are we trying to explain why it was important in the minds of the framers?:\n type: yes or no")
            
            if historical_2=="yes":
                print("\n amazing. Onto the next")
                
                while True:
                    historical_3=input("Q)3 so you have to say why something is there in the constituion \n because it was important at the time")
                
                    if historical_3=="yes":
                        print('\namazing onto the next')
                        while True:
                            
                            historical_4=input('type ( yes ) to see a list of pros to the historical argument / type anything else to see the list of the cons :')
                            
                            if historical_4=="yes":
                                print("fidelity to the intentions of the framers, authenticity")
                                break
                            else:
                                print("authenticity based on statements of individuals\n debates\n state ratification conventions\n just word of mouth")
                                break
                            
                    else:
                        print("sorry boss. try again.")
            else:
                print("sorry boss. try again ")
            
    else:
        print("sorry boss. not correct. try again ")
# Out:
# this analysis  is going to comprise of four basic questions. type (wealth) to continue: wealth
#
#  let us begin.
# Historical Arguments - Q)1 does it depend on a determination of the original understanding
#  of the constitutional provision to be construed: ? type yes or no yes
#
#  great. this is one aspect. onto the next
# Q)2 - so are we trying to explain why it was important in the minds of the framers?:
#  type: yes or nono
# sorry boss. try again
# Q)2 - so are we trying to explain why it was important in the minds of the framers?:
#  type: yes or noyes
#
#  amazing. Onto the next
# Q)3 so you have to say why something is there in the constituion
#  because it was important at the timeyes
#
# amazing onto the next

# %%
start = input("this analysis  is going to comprise of three different basic questions. type (christ) to continue: ")

if start=="christ":
    print("\n let us begin.  ")
    textual_1=input("Textual Arguments - Q)1 does this have to do with the actual words : ? type yes or no ")
    
    if textual_1=='yes':
        print("\n great. this is one aspect. onto the next ")
    
        
        
        while True:
            
            textual_2=input("Q)2 - so this is where they use the meaning of the words and the original meaning of those words?:\n type: yes or no")
            
            if textual_2=="yes":
                print("\n amazing. Onto the next")
                while True:
                    textual_3 = input("Q)3 - type (yes) for pros of this arugment. type anything else for cons:")
                
                    if textual_3=='yes':
                        print("\n the contemporary values can be intermingled with the constitution")
                        break
                    else:
                        print("\n can be anti- precedent if the words dont change. if the words dont change how can the law?")
                        break
                        
    else:
        print("sorry boss. try again")

# %%
start = input("this analysis  is going to comprise of four different basic questions. type (Israel) to continue: ")

if start=="Israel":
    print("\n let us begin.  ")
    doctrinal_1=input("Doctrinal Arguments - Q)1 do we use precedent to interpret the constitution : ? type yes or no ")
    
    if doctrinal_1=='yes':
        print("\n great. this is one aspect. onto the next ")
    
        
        
        while True:
            
            doctrinal_2=input("Q)2 - so its really not that deep we are just looking at the court had done before?:\n type: yes or no")
            
            if doctrinal_2=="yes":
                print("\n amazing. Onto the next")
                while True:
                    doctrinal_3 = input("Q)3 - type (yes) for pros of this arugment. type anything else for cons:")
                
                    if doctrinal_3=='yes':
                        print("\n easily tracked through written opinion\n distinguisehd from the arbitrariness of legislation\n more flexible than historical and textual arugments")
                        break
                    else:
                        print("\n assumes that the courts past behaviors are special and important\n assumes that the court has inherent authority?")
                        break
                        
    else:
        print("sorry boss. try again")
# Out:
# this analysis  is going to comprise of four different basic questions. type (Israel) to continue: Israel
#
#  let us begin.
# Doctrinal Arguments - Q)1 do we use precedent to interpret the constitution : ? type yes or no yes
#
#  great. this is one aspect. onto the next
# Q)2 - so its really not that deep we are just looking at the court had done before?:
#  type: yes or noyes
#
#  amazing. Onto the next
# Q)3 - type (yes) for pros of this arugment. type anything else for cons:yes
#
#  easily tracked through written opinion
#  distinguisehd from the arbitrariness of legislation
#  more flexible than historical and textual arugments
# Q)2 - so its really not that deep we are just looking at the court had done before?:
#  type: yes or noyes

# %%
start = input("this analysis  is going to comprise of four different basic questions. type (You) to continue: ")

if start=="You":
    print("\n let us begin.  ")
    prudential_1=input("Prudential Argument Q)1 - is it just a judgement or a calculation of the act against its costs : ? type yes or no ")
    
    if prudential_1=='yes':
        print("\n great. this is one aspect. onto the next ")
    
        
        
        while True:
            
            prudential_2=input("Q)2 - so I have to see weigh various factors that are relevant to a particular case\n and balance competing interests and values? : yes or no")
            
            if prudential_2=="yes":
                print("\n amazing. Onto the next")
                while True:
                    prudential_3 = input("Q)3 - So in the case of something like abortion/burning the flag\n you have to consider the type of impact the decision willl have:")
                
                    if prudential_3=='yes':
                        print("\n amazing onto the next")
                        while True:
                            prudential_4=input("type yes for some pros of this arugment or type anything else for some cons:")
                            if prudential_4=="yes":
                                print("\nthe court may introduce political realities into jurisprudence\n allows the court to carefully choose what matter to decide through law ")
                        
                            else:
                                print("approach looks determinative\n the public is invited to specualte what political consideration\n is weighed on the courts")
                    else:
                        print("\n sorry boss. try again")
                        
                        
    else:
        print("sorry boss. try again")
# Out:
# this analysis  is going to comprise of four different basic questions. type (You) to continue: You
#
#  let us begin.
# Prudential Argument Q)1 - is it just a judgement or a calculation of the act against its costs : ? type yes or no yes
#
#  great. this is one aspect. onto the next
# Q)2 - so I have to see weigh various factors that are relevant to a particular case
#  and balance competing interests and values? : yes or noyes
#
#  amazing. Onto the next
# Q)3 - So in the case of something like abortion/burning the flag
#  you have to consider the type of impact the decision willl have:yes
#
#  amazing onto the next
# type yes for some pros of this arugment or type anything else for some cons:yes
#
# the court may introduce political realities into jurisprudence
#  allows the court to carefully choose what matter to decide through law

# %%
start = input("this is going to go through four basic questions. type ( Green ) to continue:")

if start=="Green":
    print('let us begin')
    structural_1=input("Structural Arguments Q)1 - so this is just an arugment that is about how different parts of the constitution fit together: type yes or no")
    
    if structural_1=="yes":
        print("\namazing onto the next")
        while True:
            
            structural_2=input("so this is just about how different parts of the goverenment branches work together: type yes or no ")
            
            if structural_2=="yes":
                print("\namazing on the next.")
                while True:
                    structural_3=input("so this is really just about the distribution of powers?")
                    if structural_3=="yes":
                        print("\namazing onto the next ")
                        while True:
                            structural_4=input("type (yes) for some pros of the arugment. type anything else for the cons")
                            if structural_4=="yes":
                                
                                print('still grounded in text\n intuitive and simple\n permit a wide scale view of the consitution')
                    
                            else:
                                print("not adapted to matters outside of federalism - governance issues - can be contextual if the structure is everything ")
                    else:
                        
                        print('sorry boss. just try again.')
            else:
                print("sorry boss. try again.")
    else:
        print("sorry boss. try again. ")
# Out:
# this is going to go through four basic questions. type ( Green ) to continue:Green
# let us begin
# Structural Arguments Q)1 - so this is just an arugment that is about how different parts of the constitution fit together: type yes or noyes
#
# amazing onto the next
# so this is just about how different parts of the goverenment branches work together: type yes or no yes
#
# amazing on the next.
# so this is really just about the distribution of powers?yes
#
# amazing onto the next
# type (yes) for some pros of the arugment. type anything else for the consyes
# still grounded in text
#  intuitive and simple
#  permit a wide scale view of the consitution
# type (yes) for some pros of the arugment. type anything else for the consyes
# still grounded in text
#  intuitive and simple
#  permit a wide scale view of the consitution

# %%
start = input("this is going to go through four basic questions. type ( Voldemort ) to continue:")

if start=="Voldemort":
    print('let us begin')
    ethical_1=input("Ethical Arguments Q)1 - so this is just whats the right thing to do? : type yes or no")
    
    if ethical_1=="yes":
        print("\namazing onto the next")
        while True:
            
            ethical_2=input("so is this just about weighing rights vs safety: type yes or no ")
            
            if ethical_2=="yes":
                print("\namazing on the next.")
                while True:
                    ethical_3=input("type (yes) to see the pros to this. type anything else to see the cons")
                    
                    if ethical_3:
                        print("\nallows the courts to avoid results that go agaist the character of the nation")
                    
              
                    else:
                        
                        print('controveersial issues and can be undefinable what is exactly is the spirit of the united states')
            else:
                print("sorry boss. try again.")
    else:
        print("sorry boss. try again. ")
# Out:
# this is going to go through four basic questions. type ( Voldemort ) to continue:Voldemort
# let us begin
# Ethical Arguments Q)1 - so this is just whats the right thing to do? : type yes or noyes
#
# amazing onto the next
# so is this just about weighing rights vs safety: type yes or no yes
#
# amazing on the next.
# type (yes) to see the pros to this. type anything else to see the consyes
# allows the courts to avoid results that go agaist the character of the nation
